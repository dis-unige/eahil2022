# %% [markdown]
# # Open Access status for WoS DOIs
#
# Notebook used for the study presented at the EAHIL 2022 conference
#
# * Title: Computational assistance in the analysis of cited references in biomedical literature: a case study from two institutions.
#
# * Authors:
#  * Teresa Lee, Knowledge Manager, International Agency for Research on Cancer (IARC/WHO) leet@iarc.fr
#  * Pablo Iriarte, IT Coordinator, Library of the University of Geneva Pablo.Iriarte@unige.ch
#  * Floriane Muller, Librarian (Medical Library), Library of the University of Geneva Floriane.Muller@unige.ch
#  * Ramon Cierco Jimenez, Doctoral Student, International Agency for Research on Cancer (IARC/WHO) CiercoR@students.iarc.fr
#
#
# ### Prerequisites
# * DOIs from publications and citations
# * unpaywall data downloaded using the notebook "doi_unpaywall.ipynb" or queries made directly on unpaywall website
#
# ## unpaywall data extraction
#
# https://unpaywall.org/data-format
#
# Fields to extract:
#
#  - is_oa : Boolean (Is there an OA copy of this resource
#  - oa_status : Strin (The OA status, or color, of this resource: gold, hybrid, bronze, green or closed)
#  - has_repository_copy : Boolean (Whether there is a copy of this resource in a repository. True if this resource has at least one OA Location with host_type = "repository". False otherwise.)

# %%
import re
import os
import pandas as pd
import time
import datetime
import json
import numpy as np

# %% [markdown]
# ## DOIs

# %%
# open DOIs data
dois = pd.read_csv('export_dois_all_dedup.tsv', encoding='utf-8', sep='\t', header=0)
dois
# Out:
#            Accession Number                               DOI      ID
# 0       WOS:000287362000002  10.1111/j.1741-2358.2009.00330.x       1
# 1       WOS:000579849900001                 10.1111/ger.12502       2
# 2       WOS:000308547000129  10.1111/j.1741-2358.2011.00586.x       3
# 3       WOS:000331109200007                 10.1111/ger.12083       4
# 4       WOS:000450090700002        10.1016/j.jmpt.2018.01.008       5
# ...                     ...                               ...     ...
# 743544  WOS:000449710900010     10.1016/S0140-6736(08)61939-X  743545
# 743545  WOS:000449710900010         10.1017/S0033291706009159  743546
# 743546  WOS:000449710900010         10.1027/0227-5910/a000005  743547
# 743547  WOS:000449710900010         10.1016/j.aap.2013.11.015  743548
# 743548  WOS:000449710900010      10.1080/03630242.2011.637611  743549
#
# [743549 rows x 3 columns]

# %%
# del and rename cols
del dois['Accession Number']
dois = dois.rename(columns={'DOI' : 'doi', 'ID': 'id'})
dois
# Out:
#                                      doi      id
# 0       10.1111/j.1741-2358.2009.00330.x       1
# 1                      10.1111/ger.12502       2
# 2       10.1111/j.1741-2358.2011.00586.x       3
# 3                      10.1111/ger.12083       4
# 4             10.1016/j.jmpt.2018.01.008       5
# ...                                  ...     ...
# 743544     10.1016/S0140-6736(08)61939-X  743545
# 743545         10.1017/S0033291706009159  743546
# 743546         10.1027/0227-5910/a000005  743547
# 743547         10.1016/j.aap.2013.11.015  743548
# 743548      10.1080/03630242.2011.637611  743549
#
# [743549 rows x 2 columns]

# %%
# open the second series of DOIs (obtained after fixing the bug on the parsing code)
dois_2 = pd.read_csv('export_dois_without_unpaywall.tsv', encoding='utf-8', sep='\t', header=0)
dois_2
# Out:
#            id                                                doi
# 0      800001                        10.23804/ejpd.2019.20.01.11
# 1      800002                                10.3290/j.qi.a30771
# 2      800003                               10.3290/j.jad.a27795
# 3      800004                                10.3290/j.qi.a44635
# 4      800005                                10.3290/j.qi.a29751
# ...       ...                                                ...
# 11121  811122                            10.1079/PAVSNNR20094005
# 11122  811123  [10.1016/j.atherosclerosis.2019.08.014, 10.109...
# 11123  811124                                   10.1101/326470V6
# 11124  811125  [10.1016/S0140-6736(15)60401-9, 10.1016/S0140-...
# 11125  811126  [10.1016/S0140-6736(18)31694-5, 10.1016/s0140-...
#
# [11126 rows x 2 columns]

# %%
# append
dois = dois.append(dois_2, ignore_index=True)
dois
# Out:
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#                                                       doi      id
# 0                        10.1111/j.1741-2358.2009.00330.x       1
# 1                                       10.1111/ger.12502       2
# 2                        10.1111/j.1741-2358.2011.00586.x       3
# 3                                       10.1111/ger.12083       4
# 4                              10.1016/j.jmpt.2018.01.008       5
# ...                                                   ...     ...
# 754670                            10.1079/PAVSNNR20094005  811122
# 754671  [10.1016/j.atherosclerosis.2019.08.014, 10.109...  811123
# 754672                                   10.1101/326470V6  811124
# 754673  [10.1016/S0140-6736(15)60401-9, 10.1016/S0140-...  811125
# 754674  [10.1016/S0140-6736(18)31694-5, 10.1016/s0140-...  811126
#
# [754675 rows x 2 columns]

# %%
# dedup by DOI and keep only the last
dois = dois.drop_duplicates(subset='doi', keep='last')
dois
# Out:
#                                                       doi      id
# 0                        10.1111/j.1741-2358.2009.00330.x       1
# 1                                       10.1111/ger.12502       2
# 2                        10.1111/j.1741-2358.2011.00586.x       3
# 3                                       10.1111/ger.12083       4
# 4                              10.1016/j.jmpt.2018.01.008       5
# ...                                                   ...     ...
# 754670                            10.1079/PAVSNNR20094005  811122
# 754671  [10.1016/j.atherosclerosis.2019.08.014, 10.109...  811123
# 754672                                   10.1101/326470V6  811124
# 754673  [10.1016/S0140-6736(15)60401-9, 10.1016/S0140-...  811125
# 754674  [10.1016/S0140-6736(18)31694-5, 10.1016/s0140-...  811126
#
# [744569 rows x 2 columns]

# %%
# export to csv and excel
dois.to_csv('export_dois_1_and_2_dedup.tsv', sep='\t', encoding='utf-8', index=False)
dois.to_excel('export_dois_1_and_2_dedup.xlsx', index=False)

# %% [markdown]
# ## Publications from UNIGE

# %%
# open UNIGE data
unige_citations = pd.read_csv('WoS UNIGE results 2001_2020/UNIGE_WoS.csv', encoding='utf-8', header=0, usecols=['ID', 'Accession Number', 'DOI', 'DOI of cited article'])
unige_citations
# Out:
#             ID     Accession Number                               DOI  \
# 0            0  WOS:000307585400002  10.1111/j.1741-2358.2011.00508.x
# 1            1  WOS:000287362000002  10.1111/j.1741-2358.2009.00330.x
# 2            1  WOS:000287362000002  10.1111/j.1741-2358.2009.00330.x
# 3            1  WOS:000287362000002  10.1111/j.1741-2358.2009.00330.x
# 4            1  WOS:000287362000002  10.1111/j.1741-2358.2009.00330.x
# ...        ...                  ...                               ...
# 1260976  36372  WOS:000591530900014            10.1093/chemse/bjaa041
# 1260977  36372  WOS:000591530900014            10.1093/chemse/bjaa041
# 1260978  36372  WOS:000591530900014            10.1093/chemse/bjaa041
# 1260979  36372  WOS:000591530900014            10.1093/chemse/bjaa041
# 1260980  36372  WOS:000591530900014            10.1093/chemse/bjaa041
#
#                        DOI of cited article
# 0                                       NaN
# 1                                       NaN
# 2        10.1111/j.1600-0528.1999.tb02031.x
# 3              10.1177/00220345990780020301
# 4          10.1111/j.1741-2358.2001.00079.x
# ...                                     ...
# 1260976                                 NaN
# 1260977                   10.1002/alr.22577
# 1260978                   10.1002/alr.22592
# 1260979          10.1109/TPAMI.2020.2975798
# 1260980               10.1056/NEJMoa2001017
#
# [1260981 rows x 4 columns]

# %%
unige_citations.loc[unige_citations['Accession Number'].isna()]
# Out:
# Empty DataFrame
# Columns: [ID, Accession Number, DOI, DOI of cited article]
# Index: []

# %%
unige_citations.loc[unige_citations['Accession Number']=='']
# Out:
# Empty DataFrame
# Columns: [ID, Accession Number, DOI, DOI of cited article]
# Index: []

# %%
# unige publications by ID
unige_publications_rows = unige_citations[['ID', 'Accession Number', 'DOI']].drop_duplicates(subset='ID').shape[0]
unige_publications_rows
# Out:
# 36373

# %%
# unige publications
unige_publications = unige_citations[['Accession Number', 'DOI']].drop_duplicates(subset='Accession Number')
del unige_publications['Accession Number']
unige_publications = unige_publications.rename(columns={'DOI' : 'doi'})
unige_publications_dois = unige_publications.loc[unige_publications['doi'].notna()]
unige_publications_dois
# Out:
#                                       doi
# 0        10.1111/j.1741-2358.2011.00508.x
# 1        10.1111/j.1741-2358.2009.00330.x
# 48                      10.1111/ger.12502
# 83       10.1111/j.1741-2358.2011.00586.x
# 119                     10.1111/ger.12083
# ...                                   ...
# 1260758                 10.1111/bdi.12659
# 1260790              10.21037/atm-20-3754
# 1260869              10.21037/atm-2020-24
# 1260870         10.1016/j.jvs.2020.06.112
# 1260899            10.1093/chemse/bjaa041
#
# [29376 rows x 1 columns]

# %%
unige_publications
# Out:
#                                       doi
# 0        10.1111/j.1741-2358.2011.00508.x
# 1        10.1111/j.1741-2358.2009.00330.x
# 48                      10.1111/ger.12502
# 83       10.1111/j.1741-2358.2011.00586.x
# 119                     10.1111/ger.12083
# ...                                   ...
# 1260758                 10.1111/bdi.12659
# 1260790              10.21037/atm-20-3754
# 1260869              10.21037/atm-2020-24
# 1260870         10.1016/j.jvs.2020.06.112
# 1260899            10.1093/chemse/bjaa041
#
# [36370 rows x 1 columns]

# %%
# unige citations with DOIs
del unige_citations['Accession Number']
del unige_citations['ID']
del unige_citations['DOI']
unige_citations = unige_citations.rename(columns={'DOI of cited article' : 'doi'})
unige_citations_dois = unige_citations.loc[unige_citations['doi'].notna()]
unige_citations_dois
# Out:
#                                         doi
# 2        10.1111/j.1600-0528.1999.tb02031.x
# 3              10.1177/00220345990780020301
# 4          10.1111/j.1741-2358.2001.00079.x
# 5                 10.1161/01.STR.27.10.1812
# 6                 10.1161/01.STR.24.10.1478
# ...                                     ...
# 1260975           10.1007/s00415-010-5763-5
# 1260977                   10.1002/alr.22577
# 1260978                   10.1002/alr.22592
# 1260979          10.1109/TPAMI.2020.2975798
# 1260980               10.1056/NEJMoa2001017
#
# [999588 rows x 1 columns]

# %%
# open IARC data
iarc_citations = pd.read_csv('WoS IARC results 2001_2020/IARC_WoS.csv', encoding='utf-8', header=0, usecols=['Accession Number', 'DOI', 'DOI of cited article'])
iarc_citations
# Out:
#            Accession Number                            DOI  \
# 0       WOS:000492162206048                            NaN
# 1       WOS:000438342200039             10.1093/ije/dyy122
# 2       WOS:000443381100007       10.19191/EP18.1.P009.008
# 3       WOS:000443381100007       10.19191/EP18.1.P009.008
# 4       WOS:000443381100007       10.19191/EP18.1.P009.008
# ...                     ...                            ...
# 275617  WOS:000449710900010  10.1016/S0140-6736(18)32281-5
# 275618  WOS:000449710900010  10.1016/S0140-6736(18)32281-5
# 275619  WOS:000449710900010  10.1016/S0140-6736(18)32281-5
# 275620  WOS:000449710900010  10.1016/S0140-6736(18)32281-5
# 275621  WOS:000449710900010  10.1016/S0140-6736(18)32281-5
#
#                  DOI of cited article
# 0                                 NaN
# 1                  10.1093/ije/dyy063
# 2                  10.1093/ije/dyg257
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 275617                            NaN
# 275618                            NaN
# 275619                            NaN
# 275620                            NaN
# 275621  10.1016/S0140-6736(15)60265-3
#
# [275622 rows x 3 columns]

# %%
# iarc publications with DOIs
iarc_publications = iarc_citations[['Accession Number', 'DOI']].drop_duplicates(subset='Accession Number')
del iarc_publications['Accession Number']
iarc_publications = iarc_publications.rename(columns={'DOI' : 'doi'})
iarc_publications_dois = iarc_publications.loc[iarc_publications['doi'].notna()]
iarc_publications_dois
# Out:
#                                   doi
# 1                  10.1093/ije/dyy122
# 2            10.19191/EP18.1.P009.008
# 5       10.1016/S1470-2045(17)30832-X
# 20          10.1007/s40944-017-0100-x
# 48       10.1016/j.toxlet.2016.07.082
# ...                               ...
# 275178  10.1016/S0140-6736(15)00128-2
# 275264  10.1016/S0140-6736(17)32129-3
# 275318      10.1038/s41586-019-1171-x
# 275376  10.1016/S0140-6736(16)31012-1
# 275538  10.1016/S0140-6736(18)32281-5
#
# [6483 rows x 1 columns]

# %%
# iarc citations with DOIs
del iarc_citations['Accession Number']
del iarc_citations['DOI']
iarc_citations = iarc_citations.rename(columns={'DOI of cited article' : 'doi'})
iarc_citations_dois = iarc_citations.loc[iarc_citations['doi'].notna()]
iarc_citations_dois
# Out:
#                                                       doi
# 1                                      10.1093/ije/dyy063
# 2                                      10.1093/ije/dyg257
# 5                                   10.1093/carcin/bgq074
# 7                                  10.1006/faat.1993.1061
# 8                                      10.1093/aje/kwv111
# ...                                                   ...
# 275600                      10.1371/journal.pmed.1001242]
# 275601                       10.1080/03630242.2011.637611
# 275610  [10.1016/S0140-6736(16)31012-1, 10.1016/S0140-...
# 275616                10.1046/j.1360-0443.2000.95225112.x
# 275621                      10.1016/S0140-6736(15)60265-3
#
# [201591 rows x 1 columns]

# %%
# add columns
unige_publications_dois['doi'] = unige_publications_dois['doi'].str.strip()
unige_citations_dois['doi'] = unige_citations_dois['doi'].str.strip()
iarc_publications_dois['doi'] = iarc_publications_dois['doi'].str.strip()
iarc_citations_dois['doi'] = iarc_citations_dois['doi'].str.strip()
unige_publications_dois['publication_unige'] = 1
unige_citations_dois['citation_unige'] = 1
iarc_publications_dois['publication_iarc'] = 1
iarc_citations_dois['citation_iarc'] = 1
# Out:
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
# merge the publication and citation information
dois = pd.merge(dois, unige_publications_dois, on='doi', how='left')
dois = pd.merge(dois, unige_citations_dois, on='doi', how='left')
dois = pd.merge(dois, iarc_publications_dois, on='doi', how='left')
dois = pd.merge(dois, iarc_citations_dois, on='doi', how='left')
dois
# Out:
#                                                        doi      id  \
# 0                         10.1111/j.1741-2358.2009.00330.x       1
# 1                         10.1111/j.1741-2358.2009.00330.x       1
# 2                         10.1111/j.1741-2358.2009.00330.x       1
# 3                         10.1111/j.1741-2358.2009.00330.x       1
# 4                         10.1111/j.1741-2358.2009.00330.x       1
# ...                                                    ...     ...
# 1326233                            10.1079/PAVSNNR20094005  811122
# 1326234  [10.1016/j.atherosclerosis.2019.08.014, 10.109...  811123
# 1326235                                   10.1101/326470V6  811124
# 1326236  [10.1016/S0140-6736(15)60401-9, 10.1016/S0140-...  811125
# 1326237  [10.1016/S0140-6736(18)31694-5, 10.1016/s0140-...  811126
#
#          publication_unige  citation_unige  publication_iarc  citation_iarc
# 0                      1.0             1.0               NaN            NaN
# 1                      1.0             1.0               NaN            NaN
# 2                      1.0             1.0               NaN            NaN
# 3                      1.0             1.0               NaN            NaN
# 4                      1.0             1.0               NaN            NaN
# ...                    ...             ...               ...            ...
# 1326233                NaN             NaN               NaN            1.0
# 1326234                NaN             NaN               NaN            1.0
# 1326235                NaN             NaN               NaN            1.0
# 1326236                NaN             NaN               NaN            1.0
# 1326237                NaN             NaN               NaN            1.0
#
# [1326238 rows x 6 columns]

# %%
# drop duplicates
dois = dois.drop_duplicates(subset='id')
dois
# Out:
#                                                        doi      id  \
# 0                         10.1111/j.1741-2358.2009.00330.x       1
# 7                                        10.1111/ger.12502       2
# 8                         10.1111/j.1741-2358.2011.00586.x       3
# 16                                       10.1111/ger.12083       4
# 22                              10.1016/j.jmpt.2018.01.008       5
# ...                                                    ...     ...
# 1326233                            10.1079/PAVSNNR20094005  811122
# 1326234  [10.1016/j.atherosclerosis.2019.08.014, 10.109...  811123
# 1326235                                   10.1101/326470V6  811124
# 1326236  [10.1016/S0140-6736(15)60401-9, 10.1016/S0140-...  811125
# 1326237  [10.1016/S0140-6736(18)31694-5, 10.1016/s0140-...  811126
#
#          publication_unige  citation_unige  publication_iarc  citation_iarc
# 0                      1.0             1.0               NaN            NaN
# 7                      1.0             NaN               NaN            NaN
# 8                      1.0             1.0               NaN            NaN
# 16                     1.0             1.0               NaN            NaN
# 22                     1.0             NaN               NaN            NaN
# ...                    ...             ...               ...            ...
# 1326233                NaN             NaN               NaN            1.0
# 1326234                NaN             NaN               NaN            1.0
# 1326235                NaN             NaN               NaN            1.0
# 1326236                NaN             NaN               NaN            1.0
# 1326237                NaN             NaN               NaN            1.0
#
# [744569 rows x 6 columns]

# %%
# reset index
dois.reset_index(drop=True, inplace=True)
dois
# Out:
#                                                       doi      id  \
# 0                        10.1111/j.1741-2358.2009.00330.x       1
# 1                                       10.1111/ger.12502       2
# 2                        10.1111/j.1741-2358.2011.00586.x       3
# 3                                       10.1111/ger.12083       4
# 4                              10.1016/j.jmpt.2018.01.008       5
# ...                                                   ...     ...
# 744564                            10.1079/PAVSNNR20094005  811122
# 744565  [10.1016/j.atherosclerosis.2019.08.014, 10.109...  811123
# 744566                                   10.1101/326470V6  811124
# 744567  [10.1016/S0140-6736(15)60401-9, 10.1016/S0140-...  811125
# 744568  [10.1016/S0140-6736(18)31694-5, 10.1016/s0140-...  811126
#
#         publication_unige  citation_unige  publication_iarc  citation_iarc
# 0                     1.0             1.0               NaN            NaN
# 1                     1.0             NaN               NaN            NaN
# 2                     1.0             1.0               NaN            NaN
# 3                     1.0             1.0               NaN            NaN
# 4                     1.0             NaN               NaN            NaN
# ...                   ...             ...               ...            ...
# 744564                NaN             NaN               NaN            1.0
# 744565                NaN             NaN               NaN            1.0
# 744566                NaN             NaN               NaN            1.0
# 744567                NaN             NaN               NaN            1.0
# 744568                NaN             NaN               NaN            1.0
#
# [744569 rows x 6 columns]

# %%
# test empty rows
dois.loc[dois['publication_unige'].isna() & dois['citation_unige'].isna() & dois['publication_iarc'].isna() & dois['citation_iarc'].isna()]
# Out:
# Empty DataFrame
# Columns: [doi, id, publication_unige, citation_unige, publication_iarc, citation_iarc]
# Index: []

# %%
# export
dois.to_csv('export_dois_all_dedup_publications_citations.tsv', sep='\t', index=False)

# %% [markdown]
# ## unpaywall OA status

# %%
# extract informtation on downloaded data from unpaywall
for index, row in dois.iterrows():
    mydoi = row['doi']
    myid = str(row['id']).zfill(10)
    myfolder = str(int(row['id']/100000)+1)
    # print(myid)
    if (((index/1000) - int(index/1000)) == 0) :
        print(index)
    # open the json file
    if os.path.exists('E:/data_sources/unpaywall/eahil_2022/eahil_2022_' + myfolder + '/' + myid + '.json'):
        # initialising variables
        doi_unpaywall = ''
        oa_status = ''
        has_repository_copy = ''
        with open('E:/data_sources/unpaywall/eahil_2022/eahil_2022_' + myfolder + '/' + myid + '.json', 'r', encoding='utf-8') as f:
            data = json.load(f)
            if ('doi' in data):
                doi_unpaywall = data['doi']
            if ('oa_status' in data):
                oa_status = data['oa_status']
            if ('has_repository_copy' in data):
                has_repository_copy = data['has_repository_copy']

        dois.at[index,'doi_unpaywall'] = doi_unpaywall
        dois.at[index,'oa_status'] = oa_status
        dois.at[index,'has_repository_copy'] = has_repository_copy
    else :
        # print(str(row['id']) + ' - not found')
        with open('unpaywall_extract_errors.txt', 'a', encoding='utf-8') as g:
            g.write(str(row['id']) + '	file not found\n')
# Out:
# 0
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 190000
# 191000
# 192000
# 193000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 200000
# 201000
# 202000
# 203000
# 204000
# 205000
# 206000
# 207000
# 208000
# 209000
# 210000
# 211000
# 212000
# 213000
# 214000
# 215000
# 216000
# 217000
# 218000
# 219000
# 220000
# 221000
# 222000
# 223000
# 224000
# 225000
# 226000
# 227000
# 228000
# 229000
# 230000
# 231000
# 232000
# 233000
# 234000
# 235000
# 236000
# 237000
# 238000
# 239000
# 240000
# 241000
# 242000
# 243000
# 244000
# 245000
# 246000
# 247000
# 248000
# 249000
# 250000
# 251000
# 252000
# 253000
# 254000
# 255000
# 256000
# 257000
# 258000
# 259000
# 260000
# 261000
# 262000
# 263000
# 264000
# 265000
# 266000
# 267000
# 268000
# 269000
# 270000
# 271000
# 272000
# 273000
# 274000
# 275000
# 276000
# 277000
# 278000
# 279000
# 280000
# 281000
# 282000
# 283000
# 284000
# 285000
# 286000
# 287000
# 288000
# 289000
# 290000
# 291000
# 292000
# 293000
# 294000
# 295000
# 296000
# 297000
# 298000
# 299000
# 300000
# 301000
# 302000
# 303000
# 304000
# 305000
# 306000
# 307000
# 308000
# 309000
# 310000
# 311000
# 312000
# 313000
# 314000
# 315000
# 316000
# 317000
# 318000
# 319000
# 320000
# 321000
# 322000
# 323000
# 324000
# 325000
# 326000
# 327000
# 328000
# 329000
# 330000
# 331000
# 332000
# 333000
# 334000
# 335000
# 336000
# 337000
# 338000
# 339000
# 340000
# 341000
# 342000
# 343000
# 344000
# 345000
# 346000
# 347000
# 348000
# 349000
# 350000
# 351000
# 352000
# 353000
# 354000
# 355000
# 356000
# 357000
# 358000
# 359000
# 360000
# 361000
# 362000
# 363000
# 364000
# 365000
# 366000
# 367000
# 368000
# 369000
# 370000
# 371000
# 372000
# 373000
# 374000
# 375000
# 376000
# 377000
# 378000
# 379000
# 380000
# 381000
# 382000
# 383000
# 384000
# 385000
# 386000
# 387000
# 388000
# 389000
# 390000
# 391000
# 392000
# 393000
# 394000
# 395000
# 396000
# 397000
# 398000
# 399000
# 400000
# 401000
# 402000
# 403000
# 404000
# 405000
# 406000
# 407000
# 408000
# 409000
# 410000
# 411000
# 412000
# 413000
# 414000
# 415000
# 416000
# 417000
# 418000
# 419000
# 420000
# 421000
# 422000
# 423000
# 424000
# 425000
# 426000
# 427000
# 428000
# 429000
# 430000
# 431000
# 432000
# 433000
# 434000
# 435000
# 436000
# 437000
# 438000
# 439000
# 440000
# 441000
# 442000
# 443000
# 444000
# 445000
# 446000
# 447000
# 448000
# 449000
# 450000
# 451000
# 452000
# 453000
# 454000
# 455000
# 456000
# 457000
# 458000
# 459000
# 460000
# 461000
# 462000
# 463000
# 464000
# 465000
# 466000
# 467000
# 468000
# 469000
# 470000
# 471000
# 472000
# 473000
# 474000
# 475000
# 476000
# 477000
# 478000
# 479000
# 480000
# 481000
# 482000
# 483000
# 484000
# 485000
# 486000
# 487000
# 488000
# 489000
# 490000
# 491000
# 492000
# 493000
# 494000
# 495000
# 496000
# 497000
# 498000
# 499000
# 500000
# 501000
# 502000
# 503000
# 504000
# 505000
# 506000
# 507000
# 508000
# 509000
# 510000
# 511000
# 512000
# 513000
# 514000
# 515000
# 516000
# 517000
# 518000
# 519000
# 520000
# 521000
# 522000
# 523000
# 524000
# 525000
# 526000
# 527000
# 528000
# 529000
# 530000
# 531000
# 532000
# 533000
# 534000
# 535000
# 536000
# 537000
# 538000
# 539000
# 540000
# 541000
# 542000
# 543000
# 544000
# 545000
# 546000
# 547000
# 548000
# 549000
# 550000
# 551000
# 552000
# 553000
# 554000
# 555000
# 556000
# 557000
# 558000
# 559000
# 560000
# 561000
# 562000
# 563000
# 564000
# 565000
# 566000
# 567000
# 568000
# 569000
# 570000
# 571000
# 572000
# 573000
# 574000
# 575000
# 576000
# 577000
# 578000
# 579000
# 580000
# 581000
# 582000
# 583000
# 584000
# 585000
# 586000
# 587000
# 588000
# 589000
# 590000
# 591000
# 592000
# 593000
# 594000
# 595000
# 596000
# 597000
# 598000
# 599000
# 600000
# 601000
# 602000
# 603000
# 604000
# 605000
# 606000
# 607000
# 608000
# 609000
# 610000
# 611000
# 612000
# 613000
# 614000
# 615000
# 616000
# 617000
# 618000
# 619000
# 620000
# 621000
# 622000
# 623000
# 624000
# 625000
# 626000
# 627000
# 628000
# 629000
# 630000
# 631000
# 632000
# 633000
# 634000
# 635000
# 636000
# 637000
# 638000
# 639000
# 640000
# 641000
# 642000
# 643000
# 644000
# 645000
# 646000
# 647000
# 648000
# 649000
# 650000
# 651000
# 652000
# 653000
# 654000
# 655000
# 656000
# 657000
# 658000
# 659000
# 660000
# 661000
# 662000
# 663000
# 664000
# 665000
# 666000
# 667000
# 668000
# 669000
# 670000
# 671000
# 672000
# 673000
# 674000
# 675000
# 676000
# 677000
# 678000
# 679000
# 680000
# 681000
# 682000
# 683000
# 684000
# 685000
# 686000
# 687000
# 688000
# 689000
# 690000
# 691000
# 692000
# 693000
# 694000
# 695000
# 696000
# 697000
# 698000
# 699000
# 700000
# 701000
# 702000
# 703000
# 704000
# 705000
# 706000
# 707000
# 708000
# 709000
# 710000
# 711000
# 712000
# 713000
# 714000
# 715000
# 716000
# 717000
# 718000
# 719000
# 720000
# 721000
# 722000
# 723000
# 724000
# 725000
# 726000
# 727000
# 728000
# 729000
# 730000
# 731000
# 732000
# 733000
# 734000
# 735000
# 736000
# 737000
# 738000
# 739000
# 740000
# 741000
# 742000
# 743000
# 744000
# 745000
# 746000
# 747000
# 748000
# 749000
# 750000
# 751000

# %%
dois
# Out:
#                                                       doi      id  \
# 0                        10.1111/j.1741-2358.2009.00330.x       1
# 1                                       10.1111/ger.12502       2
# 2                        10.1111/j.1741-2358.2011.00586.x       3
# 3                                       10.1111/ger.12083       4
# 4                              10.1016/j.jmpt.2018.01.008       5
# ...                                                   ...     ...
# 751910                            10.1079/PAVSNNR20094005  818500
# 751911  [10.1016/j.atherosclerosis.2019.08.014, 10.109...  818501
# 751912                                   10.1101/326470V6  818502
# 751913  [10.1016/S0140-6736(15)60401-9, 10.1016/S0140-...  818503
# 751914  [10.1016/S0140-6736(18)31694-5, 10.1016/s0140-...  818504
#
#         publication_unige  citation_unige  publication_iarc  citation_iarc  \
# 0                     1.0             1.0               NaN            NaN
# 1                     1.0             NaN               NaN            NaN
# 2                     1.0             1.0               NaN            NaN
# 3                     1.0             1.0               NaN            NaN
# 4                     1.0             NaN               NaN            NaN
# ...                   ...             ...               ...            ...
# 751910                NaN             NaN               NaN            1.0
# 751911                NaN             NaN               NaN            1.0
# 751912                NaN             NaN               NaN            1.0
# 751913                NaN             NaN               NaN            1.0
# 751914                NaN             NaN               NaN            1.0
#
#                            doi_unpaywall oa_status has_repository_copy
# 0       10.1111/j.1741-2358.2009.00330.x    closed               False
# 1                      10.1111/ger.12502    closed               False
# 2       10.1111/j.1741-2358.2011.00586.x    bronze                True
# 3                      10.1111/ger.12083    closed               False
# 4             10.1016/j.jmpt.2018.01.008    closed               False
# ...                                  ...       ...                 ...
# 751910                               NaN       NaN                 NaN
# 751911                               NaN       NaN                 NaN
# 751912                               NaN       NaN                 NaN
# 751913                               NaN       NaN                 NaN
# 751914                               NaN       NaN                 NaN
#
# [751915 rows x 9 columns]

# %%
dois['oa_status'].value_counts()
# Out:
# closed    406553
# bronze    169678
# green     100580
# hybrid     37266
# gold       26712
# Name: oa_status, dtype: int64

# %%
dois['has_repository_copy'].value_counts()
# Out:
# False    518033
# True     222756
# Name: has_repository_copy, dtype: int64

# %%
# dois found
dois.loc[dois['doi_unpaywall'].notna()].shape[0]
# Out:
# 740789

# %%
# dois found
dois.loc[dois['doi_unpaywall'].notna()].shape[0] / dois.shape[0]
# Out:
# 0.9852031147137642

# %%
# dois not found
dois.loc[dois['doi_unpaywall'].isna()].shape[0]
# Out:
# 11126

# %%
# dois not found
dois.loc[dois['doi_unpaywall'].isna()].shape[0] / dois.shape[0]
# Out:
# 0.014796885286235812

# %%
# dois not equal
dois.loc[(dois['doi'] != dois['doi_unpaywall']) & dois['doi_unpaywall'].notna()]
# Out:
#                                                       doi      id  \
# 29                              10.1017/S0266462318000260      30
# 44                          10.1016/S0020-1383(15)70003-3      45
# 50                              10.1017/S0266462314000233      51
# 59                           10.1097/FPC.0b013e3280925716      61
# 60                           10.1097/FPC.0000000000000313      62
# ...                                                   ...     ...
# 749945  [10.1016/j.patol.2017.12.002, 10.1016/J.PATOL....  816535
# 749946         [10.12809/hkmj164885, 10.12809/hkmj176808]  816536
# 749947  [10.1097/qad.0000000000001765, 10.1097/QAD.000...  816537
# 749949  [10.1016/j.vaccine.2013.07.026, 10.1016/j.vacc...  816539
# 749950  [10.1016/j.mpdhp.2007.12.003, 10.1016/J.MPDHP....  816540
#
#         publication_unige  citation_unige  publication_iarc  citation_iarc  \
# 29                    1.0             1.0               NaN            NaN
# 44                    1.0             NaN               NaN            NaN
# 50                    1.0             NaN               NaN            NaN
# 59                    1.0             1.0               NaN            NaN
# 60                    1.0             NaN               NaN            NaN
# ...                   ...             ...               ...            ...
# 749945                NaN             NaN               NaN            1.0
# 749946                NaN             NaN               NaN            1.0
# 749947                NaN             NaN               NaN            1.0
# 749949                NaN             NaN               NaN            1.0
# 749950                NaN             NaN               NaN            1.0
#
#                         doi_unpaywall oa_status has_repository_copy
# 29          10.1017/s0266462318000260    closed               False
# 44      10.1016/s0020-1383(15)70003-3    closed               False
# 50          10.1017/s0266462314000233    hybrid                True
# 59       10.1097/fpc.0b013e3280925716    closed               False
# 60       10.1097/fpc.0000000000000313     green                True
# ...                               ...       ...                 ...
# 749945    10.1016/j.patol.2017.12.002    closed               False
# 749946            10.12809/hkmj164885      gold                True
# 749947   10.1097/qad.0000000000001765     green                True
# 749949  10.1016/j.vaccine.2013.07.026     green                True
# 749950    10.1016/j.mpdhp.2007.12.003    closed               False
#
# [184352 rows x 9 columns]

# %%
# normalize DOIs
dois.loc[dois['doi'].notna(), 'doi_normalized'] = dois['doi'].str.upper()
dois.loc[dois['doi_unpaywall'].notna(), 'doi_unpaywall_normalized'] = dois['doi_unpaywall'].str.upper()
dois
# Out:
#                                                       doi      id  \
# 0                        10.1111/j.1741-2358.2009.00330.x       1
# 1                                       10.1111/ger.12502       2
# 2                        10.1111/j.1741-2358.2011.00586.x       3
# 3                                       10.1111/ger.12083       4
# 4                              10.1016/j.jmpt.2018.01.008       5
# ...                                                   ...     ...
# 751910                            10.1079/PAVSNNR20094005  818500
# 751911  [10.1016/j.atherosclerosis.2019.08.014, 10.109...  818501
# 751912                                   10.1101/326470V6  818502
# 751913  [10.1016/S0140-6736(15)60401-9, 10.1016/S0140-...  818503
# 751914  [10.1016/S0140-6736(18)31694-5, 10.1016/s0140-...  818504
#
#         publication_unige  citation_unige  publication_iarc  citation_iarc  \
# 0                     1.0             1.0               NaN            NaN
# 1                     1.0             NaN               NaN            NaN
# 2                     1.0             1.0               NaN            NaN
# 3                     1.0             1.0               NaN            NaN
# 4                     1.0             NaN               NaN            NaN
# ...                   ...             ...               ...            ...
# 751910                NaN             NaN               NaN            1.0
# 751911                NaN             NaN               NaN            1.0
# 751912                NaN             NaN               NaN            1.0
# 751913                NaN             NaN               NaN            1.0
# 751914                NaN             NaN               NaN            1.0
#
#                            doi_unpaywall oa_status has_repository_copy  \
# 0       10.1111/j.1741-2358.2009.00330.x    closed               False
# 1                      10.1111/ger.12502    closed               False
# 2       10.1111/j.1741-2358.2011.00586.x    bronze                True
# 3                      10.1111/ger.12083    closed               False
# 4             10.1016/j.jmpt.2018.01.008    closed               False
# ...                                  ...       ...                 ...
# 751910                               NaN       NaN                 NaN
# 751911                               NaN       NaN                 NaN
# 751912                               NaN       NaN                 NaN
# 751913                               NaN       NaN                 NaN
# 751914                               NaN       NaN                 NaN
#
#                                            doi_normalized  \
# 0                        10.1111/J.1741-2358.2009.00330.X
# 1                                       10.1111/GER.12502
# 2                        10.1111/J.1741-2358.2011.00586.X
# 3                                       10.1111/GER.12083
# 4                              10.1016/J.JMPT.2018.01.008
# ...                                                   ...
# 751910                            10.1079/PAVSNNR20094005
# 751911  [10.1016/J.ATHEROSCLEROSIS.2019.08.014, 10.109...
# 751912                                   10.1101/326470V6
# 751913  [10.1016/S0140-6736(15)60401-9, 10.1016/S0140-...
# 751914  [10.1016/S0140-6736(18)31694-5, 10.1016/S0140-...
#
#                 doi_unpaywall_normalized
# 0       10.1111/J.1741-2358.2009.00330.X
# 1                      10.1111/GER.12502
# 2       10.1111/J.1741-2358.2011.00586.X
# 3                      10.1111/GER.12083
# 4             10.1016/J.JMPT.2018.01.008
# ...                                  ...
# 751910                               NaN
# 751911                               NaN
# 751912                               NaN
# 751913                               NaN
# 751914                               NaN
#
# [751915 rows x 11 columns]

# %%
# dois not equal
dois.loc[(dois['doi_normalized'] != dois['doi_unpaywall_normalized']) & dois['doi_unpaywall_normalized'].notna()]
# Out:
#                                                       doi      id  \
# 85157                            10.1126/science. 1068094   85952
# 122587                                   10.2307/1293082.  123860
# 122719  10.1101/gr.206602. Article published online be...  123993
# 146668                           10.1126/science. 1140516  148235
# 188852                        10.1038/S41467-019-11513-1)  191048
# ...                                                   ...     ...
# 749945  [10.1016/j.patol.2017.12.002, 10.1016/J.PATOL....  816535
# 749946         [10.12809/hkmj164885, 10.12809/hkmj176808]  816536
# 749947  [10.1097/qad.0000000000001765, 10.1097/QAD.000...  816537
# 749949  [10.1016/j.vaccine.2013.07.026, 10.1016/j.vacc...  816539
# 749950  [10.1016/j.mpdhp.2007.12.003, 10.1016/J.MPDHP....  816540
#
#         publication_unige  citation_unige  publication_iarc  citation_iarc  \
# 85157                 NaN             1.0               NaN            NaN
# 122587                NaN             1.0               NaN            NaN
# 122719                NaN             1.0               NaN            NaN
# 146668                NaN             1.0               NaN            NaN
# 188852                NaN             1.0               NaN            NaN
# ...                   ...             ...               ...            ...
# 749945                NaN             NaN               NaN            1.0
# 749946                NaN             NaN               NaN            1.0
# 749947                NaN             NaN               NaN            1.0
# 749949                NaN             NaN               NaN            1.0
# 749950                NaN             NaN               NaN            1.0
#
#                         doi_unpaywall oa_status has_repository_copy  \
# 85157                10.1126/science.    closed               False
# 122587                10.2307/1293082    closed               False
# 122719             10.1101/gr.206602.    hybrid                True
# 146668               10.1126/science.    closed               False
# 188852     10.1038/s41467-019-11513-1      gold                True
# ...                               ...       ...                 ...
# 749945    10.1016/j.patol.2017.12.002    closed               False
# 749946            10.12809/hkmj164885      gold                True
# 749947   10.1097/qad.0000000000001765     green                True
# 749949  10.1016/j.vaccine.2013.07.026     green                True
# 749950    10.1016/j.mpdhp.2007.12.003    closed               False
#
#                                            doi_normalized  \
# 85157                            10.1126/SCIENCE. 1068094
# 122587                                   10.2307/1293082.
# 122719  10.1101/GR.206602. ARTICLE PUBLISHED ONLINE BE...
# 146668                           10.1126/SCIENCE. 1140516
# 188852                        10.1038/S41467-019-11513-1)
# ...                                                   ...
# 749945  [10.1016/J.PATOL.2017.12.002, 10.1016/J.PATOL....
# 749946         [10.12809/HKMJ164885, 10.12809/HKMJ176808]
# 749947  [10.1097/QAD.0000000000001765, 10.1097/QAD.000...
# 749949  [10.1016/J.VACCINE.2013.07.026, 10.1016/J.VACC...
# 749950  [10.1016/J.MPDHP.2007.12.003, 10.1016/J.MPDHP....
#
#              doi_unpaywall_normalized
# 85157                10.1126/SCIENCE.
# 122587                10.2307/1293082
# 122719             10.1101/GR.206602.
# 146668               10.1126/SCIENCE.
# 188852     10.1038/S41467-019-11513-1
# ...                               ...
# 749945    10.1016/J.PATOL.2017.12.002
# 749946            10.12809/HKMJ164885
# 749947   10.1097/QAD.0000000000001765
# 749949  10.1016/J.VACCINE.2013.07.026
# 749950    10.1016/J.MPDHP.2007.12.003
#
# [3706 rows x 11 columns]

# %%
# dois not equal
dois.loc[(dois['doi_normalized'] != dois['doi_unpaywall_normalized']) & dois['doi_unpaywall_normalized'].notna()].shape[0]
# Out:
# 3706

# %%
# export dois not equal
dois.loc[(dois['doi_normalized'] != dois['doi_unpaywall_normalized']) & dois['doi_unpaywall_normalized'].notna()].to_excel('export_dois_wos_unpaywall_not_equal.xlsx', index=False)

# %%
# export to csv and excel
dois.to_csv('export_dois_oa_status.tsv', sep='\t', encoding='utf-8', index=False)
dois.to_excel('export_dois_oa_status.xlsx', index=False)

# %% [markdown]
# # Add OA status to publications and citations

# %%
# open UNIGE data
unige_all = pd.read_csv('WoS UNIGE results 2001_2020/UNIGE_WoS.csv', encoding='utf-8', header=0, usecols=['Accession Number', 'Document Type', 'Year Published', '29 Character Source Abbreviation', 'Open Access Indicator', 'PubMed ID', 'DOI', 'Year of cited article', 'Journal of cited article', 'DOI of cited article'])
unige_all
# Out:
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             Accession Number  Year Published Document Type  \
# 0        WOS:000307585400002            2012       Article
# 1        WOS:000287362000002            2011       Article
# 2        WOS:000287362000002            2011       Article
# 3        WOS:000287362000002            2011       Article
# 4        WOS:000287362000002            2011       Article
# ...                      ...             ...           ...
# 1260976  WOS:000591530900014            2020       Article
# 1260977  WOS:000591530900014            2020       Article
# 1260978  WOS:000591530900014            2020       Article
# 1260979  WOS:000591530900014            2020       Article
# 1260980  WOS:000591530900014            2020       Article
#
#         29 Character Source Abbreviation                               DOI  \
# 0                          GERODONTOLOGY  10.1111/j.1741-2358.2011.00508.x
# 1                          GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# 2                          GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# 3                          GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# 4                          GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# ...                                  ...                               ...
# 1260976                      CHEM SENSES            10.1093/chemse/bjaa041
# 1260977                      CHEM SENSES            10.1093/chemse/bjaa041
# 1260978                      CHEM SENSES            10.1093/chemse/bjaa041
# 1260979                      CHEM SENSES            10.1093/chemse/bjaa041
# 1260980                      CHEM SENSES            10.1093/chemse/bjaa041
#
#            PubMed ID                              Open Access Indicator  \
# 0           22591169                                                NaN
# 1           20337725                                                NaN
# 2           20337725                                                NaN
# 3           20337725                                                NaN
# 4           20337725                                                NaN
# ...              ...                                                ...
# 1260976  3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260977  3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260978  3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260979  3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260980  3.25641e+07  Green Submitted, Green Published, Green Accept...
#
#          Year of cited article Journal of cited article  \
# 0                          NaN                      NaN
# 1                       2002.0        INT J PROSTHODONT
# 2                       1999.0      COMMUNITY DENT ORAL
# 3                       1999.0               J DENT RES
# 4                       2001.0            Gerodontology
# ...                        ...                      ...
# 1260976                 2020.0         Q A COR COVID 19
# 1260977                 2020.0     INT FORUM ALLERGY RH
# 1260978                 2020.0     INT FORUM ALLERGY RH
# 1260979                 2021.0      IEEE T PATTERN ANAL
# 1260980                 2020.0           NEW ENGL J MED
#
#                        DOI of cited article
# 0                                       NaN
# 1                                       NaN
# 2        10.1111/j.1600-0528.1999.tb02031.x
# 3              10.1177/00220345990780020301
# 4          10.1111/j.1741-2358.2001.00079.x
# ...                                     ...
# 1260976                                 NaN
# 1260977                   10.1002/alr.22577
# 1260978                   10.1002/alr.22592
# 1260979          10.1109/TPAMI.2020.2975798
# 1260980               10.1056/NEJMoa2001017
#
# [1260981 rows x 10 columns]

# %%
# open IARC data
iarc_all = pd.read_csv('WoS IARC results 2001_2020/IARC_WoS.csv', encoding='utf-8', header=0, usecols=['Accession Number', 'Document Type', 'Year Published', '29 Character Source Abbreviation', 'Open Access Indicator', 'PubMed ID', 'DOI', 'Year of cited article', 'Journal of cited article', 'DOI of cited article'])
iarc_all
# Out:
#            Accession Number  Year Published       Document Type  \
# 0       WOS:000492162206048            2019    Meeting Abstract
# 1       WOS:000438342200039            2018              Letter
# 2       WOS:000443381100007            2018  Editorial Material
# 3       WOS:000443381100007            2018  Editorial Material
# 4       WOS:000443381100007            2018  Editorial Material
# ...                     ...             ...                 ...
# 275617  WOS:000449710900010            2018             Article
# 275618  WOS:000449710900010            2018             Article
# 275619  WOS:000449710900010            2018             Article
# 275620  WOS:000449710900010            2018             Article
# 275621  WOS:000449710900010            2018             Article
#
#        29 Character Source Abbreviation                            DOI  \
# 0                        J THORAC ONCOL                            NaN
# 1                       INT J EPIDEMIOL             10.1093/ije/dyy122
# 2                        EPIDEMIOL PREV       10.19191/EP18.1.P009.008
# 3                        EPIDEMIOL PREV       10.19191/EP18.1.P009.008
# 4                        EPIDEMIOL PREV       10.19191/EP18.1.P009.008
# ...                                 ...                            ...
# 275617                           LANCET  10.1016/S0140-6736(18)32281-5
# 275618                           LANCET  10.1016/S0140-6736(18)32281-5
# 275619                           LANCET  10.1016/S0140-6736(18)32281-5
# 275620                           LANCET  10.1016/S0140-6736(18)32281-5
# 275621                           LANCET  10.1016/S0140-6736(18)32281-5
#
#          PubMed ID                              Open Access Indicator  \
# 0              NaN                                                NaN
# 1              NaN                                             Bronze
# 2       29506354.0                                                NaN
# 3       29506354.0                                                NaN
# 4       29506354.0                                                NaN
# ...            ...                                                ...
# 275617  30496107.0  Green Published, Green Accepted, hybrid, Green...
# 275618  30496107.0  Green Published, Green Accepted, hybrid, Green...
# 275619  30496107.0  Green Published, Green Accepted, hybrid, Green...
# 275620  30496107.0  Green Published, Green Accepted, hybrid, Green...
# 275621  30496107.0  Green Published, Green Accepted, hybrid, Green...
#
#         Year of cited article Journal of cited article  \
# 0                         NaN                      NaN
# 1                      2018.0          INT J EPIDEMIOL
# 2                      2003.0          INT J EPIDEMIOL
# 3                      2017.0                      R P
# 4                      2016.0      LISTEN LIBERAL WHAT
# ...                       ...                      ...
# 275617                 2018.0     ATL SUST DEV GOALS 2
# 275618                 2011.0     BURD BEST BUYS RED E
# 275619                 2006.0      WORK TOG HLTH WORLD
# 275620                 2018.0     WORLD HLTH STAT 2018
# 275621                 2015.0                   LANCET
#
#                  DOI of cited article
# 0                                 NaN
# 1                  10.1093/ije/dyy063
# 2                  10.1093/ije/dyg257
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 275617                            NaN
# 275618                            NaN
# 275619                            NaN
# 275620                            NaN
# 275621  10.1016/S0140-6736(15)60265-3
#
# [275622 rows x 10 columns]

# %%
# rename columns
unige_all = unige_all.rename(columns={'Accession Number' : 'publication_wos_id',
                                      'Year Published' : 'publication_year',
                                     'Document Type' : 'publication_type',
                                     '29 Character Source Abbreviation' : 'publication_journal',
                                     'DOI' : 'publication_doi',
                                     'PubMed ID' : 'publication_pmid',
                                     'Open Access Indicator' : 'publication_wos_oa',
                                     'Year of cited article' : 'citation_year',
                                     'Journal of cited article' : 'citation_journal',
                                     'DOI of cited article' : 'citation_doi'})
unige_all
# Out:
#           publication_wos_id  publication_year publication_type  \
# 0        WOS:000307585400002              2012          Article
# 1        WOS:000287362000002              2011          Article
# 2        WOS:000287362000002              2011          Article
# 3        WOS:000287362000002              2011          Article
# 4        WOS:000287362000002              2011          Article
# ...                      ...               ...              ...
# 1260976  WOS:000591530900014              2020          Article
# 1260977  WOS:000591530900014              2020          Article
# 1260978  WOS:000591530900014              2020          Article
# 1260979  WOS:000591530900014              2020          Article
# 1260980  WOS:000591530900014              2020          Article
#
#         publication_journal                   publication_doi  \
# 0             GERODONTOLOGY  10.1111/j.1741-2358.2011.00508.x
# 1             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# 2             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# 3             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# 4             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# ...                     ...                               ...
# 1260976         CHEM SENSES            10.1093/chemse/bjaa041
# 1260977         CHEM SENSES            10.1093/chemse/bjaa041
# 1260978         CHEM SENSES            10.1093/chemse/bjaa041
# 1260979         CHEM SENSES            10.1093/chemse/bjaa041
# 1260980         CHEM SENSES            10.1093/chemse/bjaa041
#
#         publication_pmid                                 publication_wos_oa  \
# 0               22591169                                                NaN
# 1               20337725                                                NaN
# 2               20337725                                                NaN
# 3               20337725                                                NaN
# 4               20337725                                                NaN
# ...                  ...                                                ...
# 1260976      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260977      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260978      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260979      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260980      3.25641e+07  Green Submitted, Green Published, Green Accept...
#
#          citation_year      citation_journal  \
# 0                  NaN                   NaN
# 1               2002.0     INT J PROSTHODONT
# 2               1999.0   COMMUNITY DENT ORAL
# 3               1999.0            J DENT RES
# 4               2001.0         Gerodontology
# ...                ...                   ...
# 1260976         2020.0      Q A COR COVID 19
# 1260977         2020.0  INT FORUM ALLERGY RH
# 1260978         2020.0  INT FORUM ALLERGY RH
# 1260979         2021.0   IEEE T PATTERN ANAL
# 1260980         2020.0        NEW ENGL J MED
#
#                                citation_doi
# 0                                       NaN
# 1                                       NaN
# 2        10.1111/j.1600-0528.1999.tb02031.x
# 3              10.1177/00220345990780020301
# 4          10.1111/j.1741-2358.2001.00079.x
# ...                                     ...
# 1260976                                 NaN
# 1260977                   10.1002/alr.22577
# 1260978                   10.1002/alr.22592
# 1260979          10.1109/TPAMI.2020.2975798
# 1260980               10.1056/NEJMoa2001017
#
# [1260981 rows x 10 columns]

# %%
# rename columns
iarc_all = iarc_all.rename(columns={'Accession Number' : 'publication_wos_id',
                                      'Year Published' : 'publication_year',
                                     'Document Type' : 'publication_type',
                                     '29 Character Source Abbreviation' : 'publication_journal',
                                     'DOI' : 'publication_doi',
                                     'PubMed ID' : 'publication_pmid',
                                     'Open Access Indicator' : 'publication_wos_oa',
                                     'Year of cited article' : 'citation_year',
                                     'Journal of cited article' : 'citation_journal',
                                     'DOI of cited article' : 'citation_doi'})
iarc_all
# Out:
#          publication_wos_id  publication_year    publication_type  \
# 0       WOS:000492162206048              2019    Meeting Abstract
# 1       WOS:000438342200039              2018              Letter
# 2       WOS:000443381100007              2018  Editorial Material
# 3       WOS:000443381100007              2018  Editorial Material
# 4       WOS:000443381100007              2018  Editorial Material
# ...                     ...               ...                 ...
# 275617  WOS:000449710900010              2018             Article
# 275618  WOS:000449710900010              2018             Article
# 275619  WOS:000449710900010              2018             Article
# 275620  WOS:000449710900010              2018             Article
# 275621  WOS:000449710900010              2018             Article
#
#        publication_journal                publication_doi  publication_pmid  \
# 0           J THORAC ONCOL                            NaN               NaN
# 1          INT J EPIDEMIOL             10.1093/ije/dyy122               NaN
# 2           EPIDEMIOL PREV       10.19191/EP18.1.P009.008        29506354.0
# 3           EPIDEMIOL PREV       10.19191/EP18.1.P009.008        29506354.0
# 4           EPIDEMIOL PREV       10.19191/EP18.1.P009.008        29506354.0
# ...                    ...                            ...               ...
# 275617              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275618              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275619              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275620              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275621              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
#
#                                        publication_wos_oa  citation_year  \
# 0                                                     NaN            NaN
# 1                                                  Bronze         2018.0
# 2                                                     NaN         2003.0
# 3                                                     NaN         2017.0
# 4                                                     NaN         2016.0
# ...                                                   ...            ...
# 275617  Green Published, Green Accepted, hybrid, Green...         2018.0
# 275618  Green Published, Green Accepted, hybrid, Green...         2011.0
# 275619  Green Published, Green Accepted, hybrid, Green...         2006.0
# 275620  Green Published, Green Accepted, hybrid, Green...         2018.0
# 275621  Green Published, Green Accepted, hybrid, Green...         2015.0
#
#             citation_journal                   citation_doi
# 0                        NaN                            NaN
# 1            INT J EPIDEMIOL             10.1093/ije/dyy063
# 2            INT J EPIDEMIOL             10.1093/ije/dyg257
# 3                        R P                            NaN
# 4        LISTEN LIBERAL WHAT                            NaN
# ...                      ...                            ...
# 275617  ATL SUST DEV GOALS 2                            NaN
# 275618  BURD BEST BUYS RED E                            NaN
# 275619   WORK TOG HLTH WORLD                            NaN
# 275620  WORLD HLTH STAT 2018                            NaN
# 275621                LANCET  10.1016/S0140-6736(15)60265-3
#
# [275622 rows x 10 columns]

# %%
# strip DOIs
unige_all['publication_doi'] = unige_all['publication_doi'].str.strip()
unige_all['citation_doi'] = unige_all['citation_doi'].str.strip()
iarc_all['publication_doi'] = iarc_all['publication_doi'].str.strip()
iarc_all['citation_doi'] = iarc_all['citation_doi'].str.strip()

# %%
# merge in UNIGE file for publications
unige_all = pd.merge(unige_all, dois, left_on='publication_doi', right_on='doi', how='left')
unige_all
# Out:
#           publication_wos_id  publication_year publication_type  \
# 0        WOS:000307585400002              2012          Article
# 1        WOS:000287362000002              2011          Article
# 2        WOS:000287362000002              2011          Article
# 3        WOS:000287362000002              2011          Article
# 4        WOS:000287362000002              2011          Article
# ...                      ...               ...              ...
# 1260976  WOS:000591530900014              2020          Article
# 1260977  WOS:000591530900014              2020          Article
# 1260978  WOS:000591530900014              2020          Article
# 1260979  WOS:000591530900014              2020          Article
# 1260980  WOS:000591530900014              2020          Article
#
#         publication_journal                   publication_doi  \
# 0             GERODONTOLOGY  10.1111/j.1741-2358.2011.00508.x
# 1             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# 2             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# 3             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# 4             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# ...                     ...                               ...
# 1260976         CHEM SENSES            10.1093/chemse/bjaa041
# 1260977         CHEM SENSES            10.1093/chemse/bjaa041
# 1260978         CHEM SENSES            10.1093/chemse/bjaa041
# 1260979         CHEM SENSES            10.1093/chemse/bjaa041
# 1260980         CHEM SENSES            10.1093/chemse/bjaa041
#
#         publication_pmid                                 publication_wos_oa  \
# 0               22591169                                                NaN
# 1               20337725                                                NaN
# 2               20337725                                                NaN
# 3               20337725                                                NaN
# 4               20337725                                                NaN
# ...                  ...                                                ...
# 1260976      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260977      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260978      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260979      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260980      3.25641e+07  Green Submitted, Green Published, Green Accept...
#
#          citation_year      citation_journal  \
# 0                  NaN                   NaN
# 1               2002.0     INT J PROSTHODONT
# 2               1999.0   COMMUNITY DENT ORAL
# 3               1999.0            J DENT RES
# 4               2001.0         Gerodontology
# ...                ...                   ...
# 1260976         2020.0      Q A COR COVID 19
# 1260977         2020.0  INT FORUM ALLERGY RH
# 1260978         2020.0  INT FORUM ALLERGY RH
# 1260979         2021.0   IEEE T PATTERN ANAL
# 1260980         2020.0        NEW ENGL J MED
#
#                                citation_doi  ...       id  publication_unige  \
# 0                                       NaN  ...  58351.0                1.0
# 1                                       NaN  ...      1.0                1.0
# 2        10.1111/j.1600-0528.1999.tb02031.x  ...      1.0                1.0
# 3              10.1177/00220345990780020301  ...      1.0                1.0
# 4          10.1111/j.1741-2358.2001.00079.x  ...      1.0                1.0
# ...                                     ...  ...      ...                ...
# 1260976                                 NaN  ...  27766.0                1.0
# 1260977                   10.1002/alr.22577  ...  27766.0                1.0
# 1260978                   10.1002/alr.22592  ...  27766.0                1.0
# 1260979          10.1109/TPAMI.2020.2975798  ...  27766.0                1.0
# 1260980               10.1056/NEJMoa2001017  ...  27766.0                1.0
#
#          citation_unige  publication_iarc  citation_iarc  \
# 0                   1.0               NaN            NaN
# 1                   1.0               NaN            NaN
# 2                   1.0               NaN            NaN
# 3                   1.0               NaN            NaN
# 4                   1.0               NaN            NaN
# ...                 ...               ...            ...
# 1260976             1.0               NaN            NaN
# 1260977             1.0               NaN            NaN
# 1260978             1.0               NaN            NaN
# 1260979             1.0               NaN            NaN
# 1260980             1.0               NaN            NaN
#
#                             doi_unpaywall oa_status has_repository_copy  \
# 0        10.1111/j.1741-2358.2011.00508.x    closed               False
# 1        10.1111/j.1741-2358.2009.00330.x    closed               False
# 2        10.1111/j.1741-2358.2009.00330.x    closed               False
# 3        10.1111/j.1741-2358.2009.00330.x    closed               False
# 4        10.1111/j.1741-2358.2009.00330.x    closed               False
# ...                                   ...       ...                 ...
# 1260976            10.1093/chemse/bjaa041    bronze                True
# 1260977            10.1093/chemse/bjaa041    bronze                True
# 1260978            10.1093/chemse/bjaa041    bronze                True
# 1260979            10.1093/chemse/bjaa041    bronze                True
# 1260980            10.1093/chemse/bjaa041    bronze                True
#
#                            doi_normalized          doi_unpaywall_normalized
# 0        10.1111/J.1741-2358.2011.00508.X  10.1111/J.1741-2358.2011.00508.X
# 1        10.1111/J.1741-2358.2009.00330.X  10.1111/J.1741-2358.2009.00330.X
# 2        10.1111/J.1741-2358.2009.00330.X  10.1111/J.1741-2358.2009.00330.X
# 3        10.1111/J.1741-2358.2009.00330.X  10.1111/J.1741-2358.2009.00330.X
# 4        10.1111/J.1741-2358.2009.00330.X  10.1111/J.1741-2358.2009.00330.X
# ...                                   ...                               ...
# 1260976            10.1093/CHEMSE/BJAA041            10.1093/CHEMSE/BJAA041
# 1260977            10.1093/CHEMSE/BJAA041            10.1093/CHEMSE/BJAA041
# 1260978            10.1093/CHEMSE/BJAA041            10.1093/CHEMSE/BJAA041
# 1260979            10.1093/CHEMSE/BJAA041            10.1093/CHEMSE/BJAA041
# 1260980            10.1093/CHEMSE/BJAA041            10.1093/CHEMSE/BJAA041
#
# [1260981 rows x 21 columns]

# %%
# merge in UNIGE file for citations
unige_all = pd.merge(unige_all, dois, left_on='citation_doi', right_on='doi', how='left')
unige_all
# Out:
#           publication_wos_id  publication_year publication_type  \
# 0        WOS:000307585400002              2012          Article
# 1        WOS:000287362000002              2011          Article
# 2        WOS:000287362000002              2011          Article
# 3        WOS:000287362000002              2011          Article
# 4        WOS:000287362000002              2011          Article
# ...                      ...               ...              ...
# 1260976  WOS:000591530900014              2020          Article
# 1260977  WOS:000591530900014              2020          Article
# 1260978  WOS:000591530900014              2020          Article
# 1260979  WOS:000591530900014              2020          Article
# 1260980  WOS:000591530900014              2020          Article
#
#         publication_journal                   publication_doi  \
# 0             GERODONTOLOGY  10.1111/j.1741-2358.2011.00508.x
# 1             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# 2             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# 3             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# 4             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# ...                     ...                               ...
# 1260976         CHEM SENSES            10.1093/chemse/bjaa041
# 1260977         CHEM SENSES            10.1093/chemse/bjaa041
# 1260978         CHEM SENSES            10.1093/chemse/bjaa041
# 1260979         CHEM SENSES            10.1093/chemse/bjaa041
# 1260980         CHEM SENSES            10.1093/chemse/bjaa041
#
#         publication_pmid                                 publication_wos_oa  \
# 0               22591169                                                NaN
# 1               20337725                                                NaN
# 2               20337725                                                NaN
# 3               20337725                                                NaN
# 4               20337725                                                NaN
# ...                  ...                                                ...
# 1260976      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260977      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260978      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260979      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260980      3.25641e+07  Green Submitted, Green Published, Green Accept...
#
#          citation_year      citation_journal  \
# 0                  NaN                   NaN
# 1               2002.0     INT J PROSTHODONT
# 2               1999.0   COMMUNITY DENT ORAL
# 3               1999.0            J DENT RES
# 4               2001.0         Gerodontology
# ...                ...                   ...
# 1260976         2020.0      Q A COR COVID 19
# 1260977         2020.0  INT FORUM ALLERGY RH
# 1260978         2020.0  INT FORUM ALLERGY RH
# 1260979         2021.0   IEEE T PATTERN ANAL
# 1260980         2020.0        NEW ENGL J MED
#
#                                citation_doi  ...      id_y  \
# 0                                       NaN  ...       NaN
# 1                                       NaN  ...       NaN
# 2        10.1111/j.1600-0528.1999.tb02031.x  ...   33855.0
# 3              10.1177/00220345990780020301  ...   33856.0
# 4          10.1111/j.1741-2358.2001.00079.x  ...   33857.0
# ...                                     ...  ...       ...
# 1260976                                 NaN  ...       NaN
# 1260977                   10.1002/alr.22577  ...  659661.0
# 1260978                   10.1002/alr.22592  ...  659662.0
# 1260979          10.1109/TPAMI.2020.2975798  ...  659663.0
# 1260980               10.1056/NEJMoa2001017  ...   52855.0
#
#          publication_unige_y  citation_unige_y  publication_iarc_y  \
# 0                        NaN               NaN                 NaN
# 1                        NaN               NaN                 NaN
# 2                        NaN               1.0                 NaN
# 3                        NaN               1.0                 NaN
# 4                        NaN               1.0                 NaN
# ...                      ...               ...                 ...
# 1260976                  NaN               NaN                 NaN
# 1260977                  NaN               1.0                 NaN
# 1260978                  NaN               1.0                 NaN
# 1260979                  NaN               1.0                 NaN
# 1260980                  NaN               1.0                 NaN
#
#          citation_iarc_y                     doi_unpaywall_y oa_status_y  \
# 0                    NaN                                 NaN         NaN
# 1                    NaN                                 NaN         NaN
# 2                    NaN  10.1111/j.1600-0528.1999.tb02031.x      closed
# 3                    NaN        10.1177/00220345990780020301      closed
# 4                    NaN    10.1111/j.1741-2358.2001.00079.x      closed
# ...                  ...                                 ...         ...
# 1260976              NaN                                 NaN         NaN
# 1260977              NaN                   10.1002/alr.22577      closed
# 1260978              NaN                   10.1002/alr.22592      bronze
# 1260979              NaN          10.1109/tpami.2020.2975798       green
# 1260980              1.0               10.1056/nejmoa2001017      bronze
#
#         has_repository_copy_y                    doi_normalized_y  \
# 0                         NaN                                 NaN
# 1                         NaN                                 NaN
# 2                       False  10.1111/J.1600-0528.1999.TB02031.X
# 3                       False        10.1177/00220345990780020301
# 4                       False    10.1111/J.1741-2358.2001.00079.X
# ...                       ...                                 ...
# 1260976                   NaN                                 NaN
# 1260977                 False                   10.1002/ALR.22577
# 1260978                  True                   10.1002/ALR.22592
# 1260979                  True          10.1109/TPAMI.2020.2975798
# 1260980                  True               10.1056/NEJMOA2001017
#
#                  doi_unpaywall_normalized_y
# 0                                       NaN
# 1                                       NaN
# 2        10.1111/J.1600-0528.1999.TB02031.X
# 3              10.1177/00220345990780020301
# 4          10.1111/J.1741-2358.2001.00079.X
# ...                                     ...
# 1260976                                 NaN
# 1260977                   10.1002/ALR.22577
# 1260978                   10.1002/ALR.22592
# 1260979          10.1109/TPAMI.2020.2975798
# 1260980               10.1056/NEJMOA2001017
#
# [1260981 rows x 32 columns]

# %%
unige_all.columns
# Out:
# Index(['publication_wos_id', 'publication_year', 'publication_type',
#        'publication_journal', 'publication_doi', 'publication_pmid',
#        'publication_wos_oa', 'citation_year', 'citation_journal',
#        'citation_doi', 'doi_x', 'id_x', 'publication_unige_x',
#        'citation_unige_x', 'publication_iarc_x', 'citation_iarc_x',
#        'doi_unpaywall_x', 'oa_status_x', 'has_repository_copy_x',
#        'doi_normalized_x', 'doi_unpaywall_normalized_x', 'doi_y', 'id_y',
#        'publication_unige_y', 'citation_unige_y', 'publication_iarc_y',
#        'citation_iarc_y', 'doi_unpaywall_y', 'oa_status_y',
#        'has_repository_copy_y', 'doi_normalized_y',
#        'doi_unpaywall_normalized_y'],
#       dtype='object')

# %%
# merge in IARC file
iarc_all = pd.merge(iarc_all, dois, left_on='publication_doi', right_on='doi', how='left')
iarc_all
# Out:
#          publication_wos_id  publication_year    publication_type  \
# 0       WOS:000492162206048              2019    Meeting Abstract
# 1       WOS:000438342200039              2018              Letter
# 2       WOS:000443381100007              2018  Editorial Material
# 3       WOS:000443381100007              2018  Editorial Material
# 4       WOS:000443381100007              2018  Editorial Material
# ...                     ...               ...                 ...
# 275617  WOS:000449710900010              2018             Article
# 275618  WOS:000449710900010              2018             Article
# 275619  WOS:000449710900010              2018             Article
# 275620  WOS:000449710900010              2018             Article
# 275621  WOS:000449710900010              2018             Article
#
#        publication_journal                publication_doi  publication_pmid  \
# 0           J THORAC ONCOL                            NaN               NaN
# 1          INT J EPIDEMIOL             10.1093/ije/dyy122               NaN
# 2           EPIDEMIOL PREV       10.19191/EP18.1.P009.008        29506354.0
# 3           EPIDEMIOL PREV       10.19191/EP18.1.P009.008        29506354.0
# 4           EPIDEMIOL PREV       10.19191/EP18.1.P009.008        29506354.0
# ...                    ...                            ...               ...
# 275617              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275618              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275619              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275620              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275621              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
#
#                                        publication_wos_oa  citation_year  \
# 0                                                     NaN            NaN
# 1                                                  Bronze         2018.0
# 2                                                     NaN         2003.0
# 3                                                     NaN         2017.0
# 4                                                     NaN         2016.0
# ...                                                   ...            ...
# 275617  Green Published, Green Accepted, hybrid, Green...         2018.0
# 275618  Green Published, Green Accepted, hybrid, Green...         2011.0
# 275619  Green Published, Green Accepted, hybrid, Green...         2006.0
# 275620  Green Published, Green Accepted, hybrid, Green...         2018.0
# 275621  Green Published, Green Accepted, hybrid, Green...         2015.0
#
#             citation_journal                   citation_doi  ...        id  \
# 0                        NaN                            NaN  ...       NaN
# 1            INT J EPIDEMIOL             10.1093/ije/dyy063  ...   27767.0
# 2            INT J EPIDEMIOL             10.1093/ije/dyg257  ...  815391.0
# 3                        R P                            NaN  ...  815391.0
# 4        LISTEN LIBERAL WHAT                            NaN  ...  815391.0
# ...                      ...                            ...  ...       ...
# 275617  ATL SUST DEV GOALS 2                            NaN  ...   33854.0
# 275618  BURD BEST BUYS RED E                            NaN  ...   33854.0
# 275619   WORK TOG HLTH WORLD                            NaN  ...   33854.0
# 275620  WORLD HLTH STAT 2018                            NaN  ...   33854.0
# 275621                LANCET  10.1016/S0140-6736(15)60265-3  ...   33854.0
#
#         publication_unige  citation_unige  publication_iarc  citation_iarc  \
# 0                     NaN             NaN               NaN            NaN
# 1                     NaN             NaN               1.0            NaN
# 2                     NaN             NaN               1.0            NaN
# 3                     NaN             NaN               1.0            NaN
# 4                     NaN             NaN               1.0            NaN
# ...                   ...             ...               ...            ...
# 275617                NaN             NaN               1.0            NaN
# 275618                NaN             NaN               1.0            NaN
# 275619                NaN             NaN               1.0            NaN
# 275620                NaN             NaN               1.0            NaN
# 275621                NaN             NaN               1.0            NaN
#
#                         doi_unpaywall oa_status has_repository_copy  \
# 0                                 NaN       NaN                 NaN
# 1                  10.1093/ije/dyy122    bronze               False
# 2                                 NaN       NaN                 NaN
# 3                                 NaN       NaN                 NaN
# 4                                 NaN       NaN                 NaN
# ...                               ...       ...                 ...
# 275617  10.1016/s0140-6736(18)32281-5    hybrid                True
# 275618  10.1016/s0140-6736(18)32281-5    hybrid                True
# 275619  10.1016/s0140-6736(18)32281-5    hybrid                True
# 275620  10.1016/s0140-6736(18)32281-5    hybrid                True
# 275621  10.1016/s0140-6736(18)32281-5    hybrid                True
#
#                        doi_normalized       doi_unpaywall_normalized
# 0                                 NaN                            NaN
# 1                  10.1093/IJE/DYY122             10.1093/IJE/DYY122
# 2            10.19191/EP18.1.P009.008                            NaN
# 3            10.19191/EP18.1.P009.008                            NaN
# 4            10.19191/EP18.1.P009.008                            NaN
# ...                               ...                            ...
# 275617  10.1016/S0140-6736(18)32281-5  10.1016/S0140-6736(18)32281-5
# 275618  10.1016/S0140-6736(18)32281-5  10.1016/S0140-6736(18)32281-5
# 275619  10.1016/S0140-6736(18)32281-5  10.1016/S0140-6736(18)32281-5
# 275620  10.1016/S0140-6736(18)32281-5  10.1016/S0140-6736(18)32281-5
# 275621  10.1016/S0140-6736(18)32281-5  10.1016/S0140-6736(18)32281-5
#
# [275622 rows x 21 columns]

# %%
# merge in IARC file for citations
iarc_all = pd.merge(iarc_all, dois, left_on='citation_doi', right_on='doi', how='left')
iarc_all
# Out:
#          publication_wos_id  publication_year    publication_type  \
# 0       WOS:000492162206048              2019    Meeting Abstract
# 1       WOS:000438342200039              2018              Letter
# 2       WOS:000443381100007              2018  Editorial Material
# 3       WOS:000443381100007              2018  Editorial Material
# 4       WOS:000443381100007              2018  Editorial Material
# ...                     ...               ...                 ...
# 275617  WOS:000449710900010              2018             Article
# 275618  WOS:000449710900010              2018             Article
# 275619  WOS:000449710900010              2018             Article
# 275620  WOS:000449710900010              2018             Article
# 275621  WOS:000449710900010              2018             Article
#
#        publication_journal                publication_doi  publication_pmid  \
# 0           J THORAC ONCOL                            NaN               NaN
# 1          INT J EPIDEMIOL             10.1093/ije/dyy122               NaN
# 2           EPIDEMIOL PREV       10.19191/EP18.1.P009.008        29506354.0
# 3           EPIDEMIOL PREV       10.19191/EP18.1.P009.008        29506354.0
# 4           EPIDEMIOL PREV       10.19191/EP18.1.P009.008        29506354.0
# ...                    ...                            ...               ...
# 275617              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275618              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275619              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275620              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275621              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
#
#                                        publication_wos_oa  citation_year  \
# 0                                                     NaN            NaN
# 1                                                  Bronze         2018.0
# 2                                                     NaN         2003.0
# 3                                                     NaN         2017.0
# 4                                                     NaN         2016.0
# ...                                                   ...            ...
# 275617  Green Published, Green Accepted, hybrid, Green...         2018.0
# 275618  Green Published, Green Accepted, hybrid, Green...         2011.0
# 275619  Green Published, Green Accepted, hybrid, Green...         2006.0
# 275620  Green Published, Green Accepted, hybrid, Green...         2018.0
# 275621  Green Published, Green Accepted, hybrid, Green...         2015.0
#
#             citation_journal                   citation_doi  ...      id_y  \
# 0                        NaN                            NaN  ...       NaN
# 1            INT J EPIDEMIOL             10.1093/ije/dyy063  ...  659664.0
# 2            INT J EPIDEMIOL             10.1093/ije/dyg257  ...   10278.0
# 3                        R P                            NaN  ...       NaN
# 4        LISTEN LIBERAL WHAT                            NaN  ...       NaN
# ...                      ...                            ...  ...       ...
# 275617  ATL SUST DEV GOALS 2                            NaN  ...       NaN
# 275618  BURD BEST BUYS RED E                            NaN  ...       NaN
# 275619   WORK TOG HLTH WORLD                            NaN  ...       NaN
# 275620  WORLD HLTH STAT 2018                            NaN  ...       NaN
# 275621                LANCET  10.1016/S0140-6736(15)60265-3  ...   96706.0
#
#         publication_unige_y  citation_unige_y  publication_iarc_y  \
# 0                       NaN               NaN                 NaN
# 1                       NaN               NaN                 NaN
# 2                       1.0               1.0                 NaN
# 3                       NaN               NaN                 NaN
# 4                       NaN               NaN                 NaN
# ...                     ...               ...                 ...
# 275617                  NaN               NaN                 NaN
# 275618                  NaN               NaN                 NaN
# 275619                  NaN               NaN                 NaN
# 275620                  NaN               NaN                 NaN
# 275621                  NaN               1.0                 NaN
#
#         citation_iarc_y                doi_unpaywall_y oa_status_y  \
# 0                   NaN                            NaN         NaN
# 1                   1.0             10.1093/ije/dyy063      bronze
# 2                   1.0             10.1093/ije/dyg257      bronze
# 3                   NaN                            NaN         NaN
# 4                   NaN                            NaN         NaN
# ...                 ...                            ...         ...
# 275617              NaN                            NaN         NaN
# 275618              NaN                            NaN         NaN
# 275619              NaN                            NaN         NaN
# 275620              NaN                            NaN         NaN
# 275621              1.0  10.1016/s0140-6736(15)60265-3      closed
#
#        has_repository_copy_y               doi_normalized_y  \
# 0                        NaN                            NaN
# 1                      False             10.1093/IJE/DYY063
# 2                       True             10.1093/IJE/DYG257
# 3                        NaN                            NaN
# 4                        NaN                            NaN
# ...                      ...                            ...
# 275617                   NaN                            NaN
# 275618                   NaN                            NaN
# 275619                   NaN                            NaN
# 275620                   NaN                            NaN
# 275621                 False  10.1016/S0140-6736(15)60265-3
#
#            doi_unpaywall_normalized_y
# 0                                 NaN
# 1                  10.1093/IJE/DYY063
# 2                  10.1093/IJE/DYG257
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 275617                            NaN
# 275618                            NaN
# 275619                            NaN
# 275620                            NaN
# 275621  10.1016/S0140-6736(15)60265-3
#
# [275622 rows x 32 columns]

# %%
iarc_all.columns
# Out:
# Index(['publication_wos_id', 'publication_year', 'publication_type',
#        'publication_journal', 'publication_doi', 'publication_pmid',
#        'publication_wos_oa', 'citation_year', 'citation_journal',
#        'citation_doi', 'doi_x', 'id_x', 'publication_unige_x',
#        'citation_unige_x', 'publication_iarc_x', 'citation_iarc_x',
#        'doi_unpaywall_x', 'oa_status_x', 'has_repository_copy_x',
#        'doi_normalized_x', 'doi_unpaywall_normalized_x', 'doi_y', 'id_y',
#        'publication_unige_y', 'citation_unige_y', 'publication_iarc_y',
#        'citation_iarc_y', 'doi_unpaywall_y', 'oa_status_y',
#        'has_repository_copy_y', 'doi_normalized_y',
#        'doi_unpaywall_normalized_y'],
#       dtype='object')

# %%
# del columns not used and rename
del unige_all['doi_normalized_x']
del unige_all['doi_unpaywall_normalized_x']
del unige_all['doi_unpaywall_x']
del unige_all['id_x']
del unige_all['doi_x']
del unige_all['doi_normalized_y']
del unige_all['doi_unpaywall_normalized_y']
del unige_all['doi_unpaywall_y']
del unige_all['id_y']
del unige_all['doi_y']
# rename columns
unige_all = unige_all.rename(columns={'publication_unige_x' : 'publication_doi_is_unige_publication',
                                      'publication_unige_y' : 'citation_doi_is_unige_publication',
                                      'citation_unige_x' : 'publication_doi_is_unige_citation',
                                      'citation_unige_y' : 'citation_doi_is_unige_citation',
                                     'publication_iarc_x' : 'publication_doi_is_iarc_publication',
                                      'publication_iarc_y' : 'citation_doi_is_iarc_publication',
                                      'citation_iarc_x' : 'publication_doi_is_iarc_citation',
                                      'citation_iarc_y' : 'citation_doi_is_iarc_citation',
                                     'oa_status_x' : 'publication_doi_oa_status',
                                     'oa_status_y' : 'citation_doi_oa_status',
                                     'has_repository_copy_x' : 'publication_doi_has_repository_copy',
                                     'has_repository_copy_y' : 'citation_doi_has_repository_copy'})
unige_all
# Out:
#           publication_wos_id  publication_year publication_type  \
# 0        WOS:000307585400002              2012          Article
# 1        WOS:000287362000002              2011          Article
# 2        WOS:000287362000002              2011          Article
# 3        WOS:000287362000002              2011          Article
# 4        WOS:000287362000002              2011          Article
# ...                      ...               ...              ...
# 1260976  WOS:000591530900014              2020          Article
# 1260977  WOS:000591530900014              2020          Article
# 1260978  WOS:000591530900014              2020          Article
# 1260979  WOS:000591530900014              2020          Article
# 1260980  WOS:000591530900014              2020          Article
#
#         publication_journal                   publication_doi  \
# 0             GERODONTOLOGY  10.1111/j.1741-2358.2011.00508.x
# 1             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# 2             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# 3             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# 4             GERODONTOLOGY  10.1111/j.1741-2358.2009.00330.x
# ...                     ...                               ...
# 1260976         CHEM SENSES            10.1093/chemse/bjaa041
# 1260977         CHEM SENSES            10.1093/chemse/bjaa041
# 1260978         CHEM SENSES            10.1093/chemse/bjaa041
# 1260979         CHEM SENSES            10.1093/chemse/bjaa041
# 1260980         CHEM SENSES            10.1093/chemse/bjaa041
#
#         publication_pmid                                 publication_wos_oa  \
# 0               22591169                                                NaN
# 1               20337725                                                NaN
# 2               20337725                                                NaN
# 3               20337725                                                NaN
# 4               20337725                                                NaN
# ...                  ...                                                ...
# 1260976      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260977      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260978      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260979      3.25641e+07  Green Submitted, Green Published, Green Accept...
# 1260980      3.25641e+07  Green Submitted, Green Published, Green Accept...
#
#          citation_year      citation_journal  \
# 0                  NaN                   NaN
# 1               2002.0     INT J PROSTHODONT
# 2               1999.0   COMMUNITY DENT ORAL
# 3               1999.0            J DENT RES
# 4               2001.0         Gerodontology
# ...                ...                   ...
# 1260976         2020.0      Q A COR COVID 19
# 1260977         2020.0  INT FORUM ALLERGY RH
# 1260978         2020.0  INT FORUM ALLERGY RH
# 1260979         2021.0   IEEE T PATTERN ANAL
# 1260980         2020.0        NEW ENGL J MED
#
#                                citation_doi  ...  \
# 0                                       NaN  ...
# 1                                       NaN  ...
# 2        10.1111/j.1600-0528.1999.tb02031.x  ...
# 3              10.1177/00220345990780020301  ...
# 4          10.1111/j.1741-2358.2001.00079.x  ...
# ...                                     ...  ...
# 1260976                                 NaN  ...
# 1260977                   10.1002/alr.22577  ...
# 1260978                   10.1002/alr.22592  ...
# 1260979          10.1109/TPAMI.2020.2975798  ...
# 1260980               10.1056/NEJMoa2001017  ...
#
#          publication_doi_is_iarc_publication  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 1260976                                  NaN
# 1260977                                  NaN
# 1260978                                  NaN
# 1260979                                  NaN
# 1260980                                  NaN
#
#          publication_doi_is_iarc_citation  publication_doi_oa_status  \
# 0                                     NaN                     closed
# 1                                     NaN                     closed
# 2                                     NaN                     closed
# 3                                     NaN                     closed
# 4                                     NaN                     closed
# ...                                   ...                        ...
# 1260976                               NaN                     bronze
# 1260977                               NaN                     bronze
# 1260978                               NaN                     bronze
# 1260979                               NaN                     bronze
# 1260980                               NaN                     bronze
#
#          publication_doi_has_repository_copy  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ...                                      ...
# 1260976                                 True
# 1260977                                 True
# 1260978                                 True
# 1260979                                 True
# 1260980                                 True
#
#         citation_doi_is_unige_publication citation_doi_is_unige_citation  \
# 0                                     NaN                            NaN
# 1                                     NaN                            NaN
# 2                                     NaN                            1.0
# 3                                     NaN                            1.0
# 4                                     NaN                            1.0
# ...                                   ...                            ...
# 1260976                               NaN                            NaN
# 1260977                               NaN                            1.0
# 1260978                               NaN                            1.0
# 1260979                               NaN                            1.0
# 1260980                               NaN                            1.0
#
#          citation_doi_is_iarc_publication  citation_doi_is_iarc_citation  \
# 0                                     NaN                            NaN
# 1                                     NaN                            NaN
# 2                                     NaN                            NaN
# 3                                     NaN                            NaN
# 4                                     NaN                            NaN
# ...                                   ...                            ...
# 1260976                               NaN                            NaN
# 1260977                               NaN                            NaN
# 1260978                               NaN                            NaN
# 1260979                               NaN                            NaN
# 1260980                               NaN                            1.0
#
#          citation_doi_oa_status  citation_doi_has_repository_copy
# 0                           NaN                               NaN
# 1                           NaN                               NaN
# 2                        closed                             False
# 3                        closed                             False
# 4                        closed                             False
# ...                         ...                               ...
# 1260976                     NaN                               NaN
# 1260977                  closed                             False
# 1260978                  bronze                              True
# 1260979                   green                              True
# 1260980                  bronze                              True
#
# [1260981 rows x 22 columns]

# %%
unige_all.columns
# Out:
# Index(['publication_wos_id', 'publication_year', 'publication_type',
#        'publication_journal', 'publication_doi', 'publication_pmid',
#        'publication_wos_oa', 'citation_year', 'citation_journal',
#        'citation_doi', 'publication_doi_is_unige_publication',
#        'publication_doi_is_unige_citation',
#        'publication_doi_is_iarc_publication',
#        'publication_doi_is_iarc_citation', 'publication_doi_oa_status',
#        'publication_doi_has_repository_copy',
#        'citation_doi_is_unige_publication', 'citation_doi_is_unige_citation',
#        'citation_doi_is_iarc_publication', 'citation_doi_is_iarc_citation',
#        'citation_doi_oa_status', 'citation_doi_has_repository_copy'],
#       dtype='object')

# %%
del iarc_all['doi_normalized_x']
del iarc_all['doi_unpaywall_normalized_x']
del iarc_all['doi_unpaywall_x']
del iarc_all['id_x']
del iarc_all['doi_x']
del iarc_all['doi_normalized_y']
del iarc_all['doi_unpaywall_normalized_y']
del iarc_all['doi_unpaywall_y']
del iarc_all['id_y']
del iarc_all['doi_y']
# rename columns
iarc_all = iarc_all.rename(columns={'publication_unige_x' : 'publication_doi_is_unige_publication',
                                      'publication_unige_y' : 'citation_doi_is_unige_publication',
                                      'citation_unige_x' : 'publication_doi_is_unige_citation',
                                      'citation_unige_y' : 'citation_doi_is_unige_citation',
                                     'publication_iarc_x' : 'publication_doi_is_iarc_publication',
                                      'publication_iarc_y' : 'citation_doi_is_iarc_publication',
                                      'citation_iarc_x' : 'publication_doi_is_iarc_citation',
                                      'citation_iarc_y' : 'citation_doi_is_iarc_citation',
                                     'oa_status_x' : 'publication_doi_oa_status',
                                     'oa_status_y' : 'citation_doi_oa_status',
                                     'has_repository_copy_x' : 'publication_doi_has_repository_copy',
                                     'has_repository_copy_y' : 'citation_doi_has_repository_copy'})
iarc_all
# Out:
#          publication_wos_id  publication_year    publication_type  \
# 0       WOS:000492162206048              2019    Meeting Abstract
# 1       WOS:000438342200039              2018              Letter
# 2       WOS:000443381100007              2018  Editorial Material
# 3       WOS:000443381100007              2018  Editorial Material
# 4       WOS:000443381100007              2018  Editorial Material
# ...                     ...               ...                 ...
# 275617  WOS:000449710900010              2018             Article
# 275618  WOS:000449710900010              2018             Article
# 275619  WOS:000449710900010              2018             Article
# 275620  WOS:000449710900010              2018             Article
# 275621  WOS:000449710900010              2018             Article
#
#        publication_journal                publication_doi  publication_pmid  \
# 0           J THORAC ONCOL                            NaN               NaN
# 1          INT J EPIDEMIOL             10.1093/ije/dyy122               NaN
# 2           EPIDEMIOL PREV       10.19191/EP18.1.P009.008        29506354.0
# 3           EPIDEMIOL PREV       10.19191/EP18.1.P009.008        29506354.0
# 4           EPIDEMIOL PREV       10.19191/EP18.1.P009.008        29506354.0
# ...                    ...                            ...               ...
# 275617              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275618              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275619              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275620              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
# 275621              LANCET  10.1016/S0140-6736(18)32281-5        30496107.0
#
#                                        publication_wos_oa  citation_year  \
# 0                                                     NaN            NaN
# 1                                                  Bronze         2018.0
# 2                                                     NaN         2003.0
# 3                                                     NaN         2017.0
# 4                                                     NaN         2016.0
# ...                                                   ...            ...
# 275617  Green Published, Green Accepted, hybrid, Green...         2018.0
# 275618  Green Published, Green Accepted, hybrid, Green...         2011.0
# 275619  Green Published, Green Accepted, hybrid, Green...         2006.0
# 275620  Green Published, Green Accepted, hybrid, Green...         2018.0
# 275621  Green Published, Green Accepted, hybrid, Green...         2015.0
#
#             citation_journal                   citation_doi  ...  \
# 0                        NaN                            NaN  ...
# 1            INT J EPIDEMIOL             10.1093/ije/dyy063  ...
# 2            INT J EPIDEMIOL             10.1093/ije/dyg257  ...
# 3                        R P                            NaN  ...
# 4        LISTEN LIBERAL WHAT                            NaN  ...
# ...                      ...                            ...  ...
# 275617  ATL SUST DEV GOALS 2                            NaN  ...
# 275618  BURD BEST BUYS RED E                            NaN  ...
# 275619   WORK TOG HLTH WORLD                            NaN  ...
# 275620  WORLD HLTH STAT 2018                            NaN  ...
# 275621                LANCET  10.1016/S0140-6736(15)60265-3  ...
#
#         publication_doi_is_iarc_publication  publication_doi_is_iarc_citation  \
# 0                                       NaN                               NaN
# 1                                       1.0                               NaN
# 2                                       1.0                               NaN
# 3                                       1.0                               NaN
# 4                                       1.0                               NaN
# ...                                     ...                               ...
# 275617                                  1.0                               NaN
# 275618                                  1.0                               NaN
# 275619                                  1.0                               NaN
# 275620                                  1.0                               NaN
# 275621                                  1.0                               NaN
#
#         publication_doi_oa_status  publication_doi_has_repository_copy  \
# 0                             NaN                                  NaN
# 1                          bronze                                False
# 2                             NaN                                  NaN
# 3                             NaN                                  NaN
# 4                             NaN                                  NaN
# ...                           ...                                  ...
# 275617                     hybrid                                 True
# 275618                     hybrid                                 True
# 275619                     hybrid                                 True
# 275620                     hybrid                                 True
# 275621                     hybrid                                 True
#
#        citation_doi_is_unige_publication citation_doi_is_unige_citation  \
# 0                                    NaN                            NaN
# 1                                    NaN                            NaN
# 2                                    1.0                            1.0
# 3                                    NaN                            NaN
# 4                                    NaN                            NaN
# ...                                  ...                            ...
# 275617                               NaN                            NaN
# 275618                               NaN                            NaN
# 275619                               NaN                            NaN
# 275620                               NaN                            NaN
# 275621                               NaN                            1.0
#
#         citation_doi_is_iarc_publication  citation_doi_is_iarc_citation  \
# 0                                    NaN                            NaN
# 1                                    NaN                            1.0
# 2                                    NaN                            1.0
# 3                                    NaN                            NaN
# 4                                    NaN                            NaN
# ...                                  ...                            ...
# 275617                               NaN                            NaN
# 275618                               NaN                            NaN
# 275619                               NaN                            NaN
# 275620                               NaN                            NaN
# 275621                               NaN                            1.0
#
#         citation_doi_oa_status  citation_doi_has_repository_copy
# 0                          NaN                               NaN
# 1                       bronze                             False
# 2                       bronze                              True
# 3                          NaN                               NaN
# 4                          NaN                               NaN
# ...                        ...                               ...
# 275617                     NaN                               NaN
# 275618                     NaN                               NaN
# 275619                     NaN                               NaN
# 275620                     NaN                               NaN
# 275621                  closed                             False
#
# [275622 rows x 22 columns]

# %%
iarc_all.columns
# Out:
# Index(['publication_wos_id', 'publication_year', 'publication_type',
#        'publication_journal', 'publication_doi', 'publication_pmid',
#        'publication_wos_oa', 'citation_year', 'citation_journal',
#        'citation_doi', 'publication_doi_is_unige_publication',
#        'publication_doi_is_unige_citation',
#        'publication_doi_is_iarc_publication',
#        'publication_doi_is_iarc_citation', 'publication_doi_oa_status',
#        'publication_doi_has_repository_copy',
#        'citation_doi_is_unige_publication', 'citation_doi_is_unige_citation',
#        'citation_doi_is_iarc_publication', 'citation_doi_is_iarc_citation',
#        'citation_doi_oa_status', 'citation_doi_has_repository_copy'],
#       dtype='object')

# %%
# export of dois without unpaywall information to test a new download
unige_publications_with_dois_without_unpaywall = unige_all.loc[unige_all['publication_doi'].notna() & unige_all['publication_doi_oa_status'].isna()][['publication_wos_id', 'publication_doi']]
unige_citations_with_dois_without_unpaywall = unige_all.loc[unige_all['citation_doi'].notna() & unige_all['citation_doi_oa_status'].isna()][['publication_wos_id', 'citation_doi']]
iarc_publications_with_dois_without_unpaywall = iarc_all.loc[iarc_all['publication_doi'].notna() & iarc_all['publication_doi_oa_status'].isna()][['publication_wos_id', 'publication_doi']]
iarc_citations_with_dois_without_unpaywall = iarc_all.loc[iarc_all['citation_doi'].notna() & iarc_all['citation_doi_oa_status'].isna()][['publication_wos_id', 'citation_doi']]
# rename columns
unige_publications_with_dois_without_unpaywall = unige_publications_with_dois_without_unpaywall.rename(columns={'publication_doi' : 'doi'})
unige_citations_with_dois_without_unpaywall = unige_citations_with_dois_without_unpaywall.rename(columns={'citation_doi' : 'doi'})
iarc_publications_with_dois_without_unpaywall = iarc_publications_with_dois_without_unpaywall.rename(columns={'publication_doi' : 'doi'})
iarc_citations_with_dois_without_unpaywall = iarc_citations_with_dois_without_unpaywall.rename(columns={'citation_doi' : 'doi'})

# %%
# append dfs and reindex
dois_without_unpaywall = unige_publications_with_dois_without_unpaywall.append(unige_citations_with_dois_without_unpaywall, ignore_index=True)
dois_without_unpaywall = dois_without_unpaywall.append(iarc_publications_with_dois_without_unpaywall, ignore_index=True)
dois_without_unpaywall = dois_without_unpaywall.append(iarc_citations_with_dois_without_unpaywall, ignore_index=True)
# dedup
dois_without_unpaywall = dois_without_unpaywall.drop_duplicates(subset='doi')
# reset index
dois_without_unpaywall.reset_index(drop=True, inplace=True)
# add new id
dois_without_unpaywall['id'] = dois_without_unpaywall.index + 800001
dois_without_unpaywall
# Out:
#         publication_wos_id                                                doi  \
# 0      WOS:000493407400011                        10.23804/ejpd.2019.20.01.11
# 1      WOS:000330287600007                                10.3290/j.qi.a30771
# 2      WOS:000312468300009                               10.3290/j.jad.a27795
# 3      WOS:000541911400003                                10.3290/j.qi.a44635
# 4      WOS:000329520000003                                10.3290/j.qi.a29751
# ...                    ...                                                ...
# 11121  WOS:000380844300001                            10.1079/PAVSNNR20094005
# 11122  WOS:000562463000002  [10.1016/j.atherosclerosis.2019.08.014, 10.109...
# 11123  WOS:000529097800007                                   10.1101/326470V6
# 11124  WOS:000385285000007  [10.1016/S0140-6736(15)60401-9, 10.1016/S0140-...
# 11125  WOS:000449710900010  [10.1016/S0140-6736(18)31694-5, 10.1016/s0140-...
#
#            id
# 0      800001
# 1      800002
# 2      800003
# 3      800004
# 4      800005
# ...       ...
# 11121  811122
# 11122  811123
# 11123  811124
# 11124  811125
# 11125  811126
#
# [11126 rows x 3 columns]

# %%
dois_without_unpaywall[['id', 'doi']].to_csv('export_dois_without_unpaywall.tsv', sep='\t', index=False)

# %%
# export files
unige_all.to_csv('unige_all_oa_status_citations.csv', sep='\t', index=False, encoding='utf-8')
# unige_all.to_excel('unige_all_oa_status_citations.xlsx', index=False)
iarc_all.to_csv('iarc_all_oa_status_citations.csv', sep='\t', index=False, encoding='utf-8')
iarc_all.to_excel('iarc_all_oa_status_citations.xlsx', index=False)
